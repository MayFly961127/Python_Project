# %%
import math
def nCk(n,k):
    Combi = math.factorial(n)/(math.factorial(n-k)*math.factorial(k))
    return Combi
# Out:
# 6.0

# %%
n = 100
c = 1
k = c + 1
probability_r = 0.1
probability_c = 1 - probability_r
Bern = 0
for i in range(k, n +1):
    Bern += nCk(n,i)*(probability_r**i)*(probability_c**(n-i))
Bern
# Out:
# 0.9996783119468085

# %%
cd ~
# Out:
# /Users/seunghwankim

# %%
cd PycharmProjects/Python_Project/MayFly_Finance/Project_vol1
# Out:
# /Users/seunghwankim/PycharmProjects/Python_Project/MayFly_Finance/Project_vol1

# %%
from Trend_Dev import Trend_Dev
Trend_Dev('^DJI','UPS',36,15,9)
# Out:
# ['Dow', '^DJI', '\nS&P', 'GSPC', '\nNAS', '^IXIC']
# Trend_dv_dn  36
# Trend_dv_nu  15
# Trend_dv_MV 9

# %%
U_good = 0.5
U_ = 0.125
U_bad = -0.25
R_good = 0.5
R_ = 0.125
R_bad = -0.25
Probability = 0.5
COV_UR = Probability*(U_good - U_)*(R_bad - R_) + (1 - Probability)*(U_bad - U_)*(R_good - R_)
if COV_UR == 1.0:
    print('위험 감소 불가능')
elif COV_UR >= 0.5 and COV_UR < 1.0:
    print('약간의 위험 감소')
elif COV_UR >= 0 and COV_UR < 0.5:
    print('상당한 위험 감소')
elif COV_UR < 0 and COV_UR >= -0.5:
    print('대부분의 위험 제거')
elif COV_UR >= -1.0 and COV_UR < 0.5:
    print('모든 위험 제거')
# Out:
# 대부분의 위험 제거

# %%
def PEG(PE, EV):
    return PE/EV

# %%
import yfinance as yfin
import pandas_datareader as pdr
import matplotlib.pyplot as plt
yfin.pdr_override()

df_SOFI = pdr.get_data_yahoo('SOFI')
df_SOFI = df_SOFI.reset_index()
df_SOFI = df_SOFI[df_SOFI['Date'] >= '2021-11-01']
df_SOFI = df_SOFI['Close']
plt.plot(df_SOFI)

# %%
# !pip install yahoo_fin
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 6.8 MB/s eta 0:00:011
# Requirement already satisfied: requests in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from yahoo_fin) (2.27.1)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from yahoo_fin) (1.4.1)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from pandas->yahoo_fin) (1.21.2)
# Requirement already satisfied: six>=1.5 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from requests->yahoo_fin) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from requests->yahoo_fin) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from requests->yahoo_fin) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from requests->yahoo_fin) (2020.6.20)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 6.9 MB/s  eta 0:00:01
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting tqdm<5.0.0,>=4.42.1
#   Downloading tqdm-4.63.1-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 9.0 MB/s eta 0:00:011
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.2-cp310-cp310-macosx_10_9_x86_64.whl (96 kB)
#      |████████████████████████████████| 96 kB 11.2 MB/s eta 0:00:01
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.2)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 19.3 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=0.5 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.7.0)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 15.0 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: lxml>=2.1 in /Users/seunghwankim/.conda/envs/pythonProject/lib/python3.10/site-packages (from pyquery->requests-html->yahoo_fin) (4.8.0)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: bs4, fake-useragent, parse, sgmllib3k
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=20b101e23f5fa0b919adf5f80cdf2ff69a8b35988750069c62a342c9edc79bca
#   Stored in directory: /Users/seunghwankim/Library/Caches/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=27467e7ea44461c1725cc3ee0dadfca04ffe4c4de213b3b74aed91d8c7343449
#   Stored in directory: /Users/seunghwankim/Library/Caches/pip/wheels/ad/4f/20/1880f6cbdf5e12b5fa9635d072735ea0842db7346939891812
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=50250464460ded03e4c428381a89975504da69d6cb67d8597d5e9b514791a583
#   Stored in directory: /Users/seunghwankim/Library/Caches/pip/wheels/70/4b/f0/eaf5a8de646d8676dc25caa01949b9f9d883b8fa2efb435bc3
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=d295e934c449696464e5223ecd361a87c7192e346fe63646d47cda446935d10c
#   Stored in directory: /Users/seunghwankim/Library/Caches/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built bs4 fake-useragent parse sgmllib3k
# Installing collected packages: soupsieve, websockets, tqdm, pyee, cssselect, certifi, beautifulsoup4, appdirs, w3lib, sgmllib3k, pyquery, pyppeteer, parse, fake-useragent, bs4, requests-html, feedparser, yahoo-fin
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.6.20
#     Uninstalling certifi-2020.6.20:
#       Successfully uninstalled certifi-2020.6.20
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.10.0 bs4-0.0.1 certifi-2021.10.8 cssselect-1.1.0 fake-useragent-0.1.11 feedparser-6.0.8 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sgmllib3k-1.0.0 soupsieve-2.3.1 tqdm-4.63.1 w3lib-1.22.0 websockets-10.2 yahoo-fin-0.8.9.1

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
def func_SOFI(x,a,b,c):
    import numpy as np
    return a*np.exp(-b*x) +c

x_SOFI = np.linspace(0, len(df_SOFI), len(df_SOFI))
y_SOFI = np.reshape(df_SOFI.to_numpy(),len(df_SOFI))
popt, *_ = curve_fit(func_SOFI, x_SOFI, y_SOFI)
popt

y_fit_SOFI = [popt[0]*np.exp(-popt[1]*x) + popt[2] for x in x_SOFI]
plt.plot(x_SOFI,y_SOFI, 'o')
plt.plot(x_SOFI, y_fit_SOFI, '-')
plt.show()
# Out:
# /var/folders/l9/glqlxsms6kg26pc8n2s189hw0000gn/T/ipykernel_1198/3771528295.py:6: RuntimeWarning: overflow encountered in exp
#   return a*np.exp(-b*x) +c

# %%
import yahoo_fin.stock_info as yf
balance_SOFI = yf.get_balance_sheet('SOFI')
balance_SOFI = balance_SOFI['2021-12-31']
balance_SOFI = balance_SOFI['totalAssets']

# %%
balance_SOFI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 balance_SOFI
#
# NameError: name 'balance_SOFI' is not defined

# %%
func = lambda x,y: x + y**2
from functools import partial
func_x = partial(func,2)
func_x(3)

mul = [[f'{i} x {j} = {i*j}' for j in range(1,10)] for i in range(2,10)]
mul
# Out:
# [['2 x 1 = 2',
#   '2 x 2 = 4',
#   '2 x 3 = 6',
#   '2 x 4 = 8',
#   '2 x 5 = 10',
#   '2 x 6 = 12',
#   '2 x 7 = 14',
#   '2 x 8 = 16',
#   '2 x 9 = 18'],
#  ['3 x 1 = 3',
#   '3 x 2 = 6',
#   '3 x 3 = 9',
#   '3 x 4 = 12',
#   '3 x 5 = 15',
#   '3 x 6 = 18',
#   '3 x 7 = 21',
#   '3 x 8 = 24',
#   '3 x 9 = 27'],
#  ['4 x 1 = 4',
#   '4 x 2 = 8',
#   '4 x 3 = 12',
#   '4 x 4 = 16',
#   '4 x 5 = 20',
#   '4 x 6 = 24',
#   '4 x 7 = 28',
#   '4 x 8 = 32',
#   '4 x 9 = 36'],
#  ['5 x 1 = 5',
#   '5 x 2 = 10',
#   '5 x 3 = 15',
#   '5 x 4 = 20',
#   '5 x 5 = 25',
#   '5 x 6 = 30',
#   '5 x 7 = 35',
#   '5 x 8 = 40',
#   '5 x 9 = 45'],
#  ['6 x 1 = 6',
#   '6 x 2 = 12',
#   '6 x 3 = 18',
#   '6 x 4 = 24',
#   '6 x 5 = 30',
#   '6 x 6 = 36',
#   '6 x 7 = 42',
#   '6 x 8 = 48',
#   '6 x 9 = 54'],
#  ['7 x 1 = 7',
#   '7 x 2 = 14',
#   '7 x 3 = 21',
#   '7 x 4 = 28',
#   '7 x 5 = 35',
#   '7 x 6 = 42',
#   '7 x 7 = 49',
#   '7 x 8 = 56',
#   '7 x 9 = 63'],
#  ['8 x 1 = 8',
#   '8 x 2 = 16',
#   '8 x 3 = 24',
#   '8 x 4 = 32',
#   '8 x 5 = 40',
#   '8 x 6 = 48',
#   '8 x 7 = 56',
#   '8 x 8 = 64',
#   '8 x 9 = 72'],
#  ['9 x 1 = 9',
#   '9 x 2 = 18',
#   '9 x 3 = 27',
#   '9 x 4 = 36',
#   '9 x 5 = 45',
#   '9 x 6 = 54',
#   '9 x 7 = 63',
#   '9 x 8 = 72',
#   '9 x 9 = 81']]

# %%
from nltk.corpus import names
a = names.words()[:11]
b = names.words()[11:21]
c = [a,b]
d = [name for names in c for name in names if len(name) >= 6]
d
# Out:
# ['Abagael', 'Abagail', 'Abigael', 'Abigail', 'Abigale', 'Adaline', 'Adelaide']

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.10.1-py3-none-any.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 7.9 MB/s eta 0:00:01
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      |████████████████████████████████| 532 kB 9.4 MB/s eta 0:00:01
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.2.1 sympy-1.10.1

# %%
from sympy import Eq, symbols, factorial, solve

n = symbols('k')
eq = Eq((factorial(50)/(factorial(k)*factorial(50-k)))/(factorial(100)/(factorial(k)*factorial(100-k))) - 0.01)
solve(eq)
# Out:
# /var/folders/l9/glqlxsms6kg26pc8n2s189hw0000gn/T/ipykernel_2589/646834547.py:4: SymPyDeprecationWarning:
#
# Eq(expr) with a single argument with the right-hand side
# defaulting to 0 is deprecated. Use Eq(expr, 0) instead.
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#deprecated-eq-expr
# for details.
#
# This has been deprecated since SymPy version 1.5. It
# will be removed in a future version of SymPy.
#
#   eq = Eq((factorial(50)/(factorial(k)*factorial(50-k)))/(factorial(100)/(factorial(k)*factorial(100-k))) - 0.01)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [12], in <cell line: 5>()
#       3 n = symbols('k')
#       4 eq = Eq((factorial(50)/(factorial(k)*factorial(50-k)))/(factorial(100)/(factorial(k)*factorial(100-k))) - 0.01)
# ----> 5 solve(eq)
#
# File ~/.conda/envs/pythonProject/lib/python3.10/site-packages/sympy/solvers/solvers.py:1106, in solve(f, *symbols, **flags)
#    1102 #
#    1103 # try to get a solution
#    1104 ###########################################################################
#    1105 if bare_f:
# -> 1106     solution = _solve(f[0], *symbols, **flags)
#    1107 else:
#    1108     solution = _solve_system(f, symbols, **flags)
#
# File ~/.conda/envs/pythonProject/lib/python3.10/site-packages/sympy/solvers/solvers.py:1720, in _solve(f, *symbols, **flags)
#    1717 # ----------- end of fallback ----------------------------
#    1719 if result is False:
# -> 1720     raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1722 if flags.get('simplify', True):
#    1723     result = list(map(simplify, result))
#
# NotImplementedError: multiple generators [factorial(100 - k), factorial(50 - k)]
# No algorithms are implemented to solve equation -1/100 + factorial(100 - k)/(3068518756254966037202730459529469739228459721684688959447786986982158958772355072000000000000*factorial(50 - k))

# %%
cd ~
# Out:
# /Users/seunghwankim

# %%
cd PycharmProjects/Python_Project/MayFly_Finance/Project_vol1
# Out:
# /Users/seunghwankim/PycharmProjects/Python_Project/MayFly_Finance/Project_vol1

# %%
from Trend_Dev import Trend_Dev
Trend_Dev('SFY',15,9,6)
# Out:
# Trend_dv_dn  15
# Trend_dv_nu  9
# Trend_dv_MV 6
